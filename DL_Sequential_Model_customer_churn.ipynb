# %% [markdown]
# ### ANN With Cutomer Churn Prediction- Classification

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\win10\anaconda3\envs\myenv\lib\site-packages (1.1.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\win10\anaconda3\envs\myenv\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\win10\anaconda3\envs\myenv\lib\site-packages (from pandas) (1.19.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\win10\anaconda3\envs\myenv\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\win10\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
corr = dataset.corr()

# %%
import seaborn as sns

# %%
plt.hist()

# %%
plt.scatter?

# %%
plt.figure(figsize=(8, 6))

# %%
plt.figure(figsize=(15, 6))
plt.scatter(dataset['NumOfProducts'],dataset["Age"], c=y, )

# %%
plt.figure(figsize=(15, 6))
plt.scatter(dataset["CreditScore"],dataset["Age"], c=y, )

# %%
for col in X.columns:
    print(col.upper())
    plt.hist(dataset[col], bins=20)
    plt.show()
# Out:
# CREDITSCORE
# GEOGRAPHY
# GENDER
# AGE
# TENURE
# BALANCE
# NUMOFPRODUCTS
# HASCRCARD
# ISACTIVEMEMBER
# ESTIMATEDSALARY

# %%
plt.scatter(dataset["CreditScore"],y)

# %%
k=dataset.corr()

# %%
k
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber       -0.009067       0.007246   0.000599        0.012044
# CustomerId      -0.012419       0.016972  -0.014025        0.001665
# CreditScore      0.006268       0.012238  -0.005458        0.025651
# Age              0.028308      -0.030680  -0.011721        0.085472
# Tenure          -0.012254       0.013444   0.022583       -0.028362
# Balance          1.000000      -0.304180  -0.014858       -0.010084
# NumOfProducts   -0.304180       1.000000   0.003183        0.009612
# HasCrCard       -0.014858       0.003183   1.000000       -0.011866
# IsActiveMember  -0.010084       0.009612  -0.011866        1.000000
# EstimatedSalary  0.012797       0.014204  -0.009933       -0.011421
# Exited           0.118533      -0.047820  -0.007138       -0.156128
#
#                  EstimatedSalary    Exited
# RowNumber              -0.005988 -0.016571
# CustomerId              0.015271 -0.006248
# CreditScore            -0.001384 -0.027094
# Age                    -0.007201  0.285323
# Tenure                  0.007784 -0.014001
# Balance                 0.012797  0.118533
# NumOfProducts           0.014204 -0.047820
# HasCrCard              -0.009933 -0.007138
# IsActiveMember         -0.011421 -0.156128
# EstimatedSalary         1.000000  0.012097
# Exited                  0.012097  1.000000

# %%
k["Age"].sort_values(ascending=True)[:2]
# Out:
# NumOfProducts   -0.030680
# HasCrCard       -0.011721
# Name: Age, dtype: float64

# %%
k["Age"].sort_values(ascending=False)[1:3]
# Out:
# Exited            0.285323
# IsActiveMember    0.085472
# Name: Age, dtype: float64

# %%
for col in k:
    k.col
# Out:
#            RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# RowNumber        1.0    0.004202      0.00584  0.000783 -0.006495 -0.009067
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# RowNumber       0.007246   0.000599        0.012044        -0.005988 -0.016571
#             RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# CustomerId   0.004202         1.0     0.005308  0.009497 -0.014883 -0.012419
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# CustomerId       0.016972  -0.014025        0.001665         0.015271
#
#               Exited
# CustomerId -0.006248
#              RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# CreditScore    0.00584    0.005308          1.0 -0.003965  0.000842  0.006268
#
#              NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# CreditScore       0.012238  -0.005458        0.025651        -0.001384
#
#                Exited
# CreditScore -0.027094
#      RowNumber  CustomerId  CreditScore  Age    Tenure   Balance  \
# Age   0.000783    0.009497    -0.003965  1.0 -0.009997  0.028308
#
#      NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# Age       -0.03068  -0.011721        0.085472        -0.007201  0.285323
#         RowNumber  CustomerId  CreditScore       Age  Tenure   Balance  \
# Tenure  -0.006495   -0.014883     0.000842 -0.009997     1.0 -0.012254
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# Tenure       0.013444   0.022583       -0.028362         0.007784 -0.014001
#          RowNumber  CustomerId  CreditScore       Age    Tenure  Balance  \
# Balance  -0.009067   -0.012419     0.006268  0.028308 -0.012254      1.0
#
#          NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# Balance       -0.30418  -0.014858       -0.010084         0.012797  0.118533
#                RowNumber  CustomerId  CreditScore      Age    Tenure  Balance  \
# NumOfProducts   0.007246    0.016972     0.012238 -0.03068  0.013444 -0.30418
#
#                NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# NumOfProducts            1.0   0.003183        0.009612         0.014204
#
#                 Exited
# NumOfProducts -0.04782
#            RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# HasCrCard   0.000599   -0.014025    -0.005458 -0.011721  0.022583 -0.014858
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# HasCrCard       0.003183        1.0       -0.011866        -0.009933 -0.007138
#                 RowNumber  CustomerId  CreditScore       Age    Tenure  \
# IsActiveMember   0.012044    0.001665     0.025651  0.085472 -0.028362
#
#                  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# IsActiveMember -0.010084       0.009612  -0.011866             1.0
#
#                 EstimatedSalary    Exited
# IsActiveMember        -0.011421 -0.156128
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# EstimatedSalary  0.012797       0.014204  -0.009933       -0.011421
#
#                  EstimatedSalary    Exited
# EstimatedSalary              1.0  0.012097
#         RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# Exited  -0.016571   -0.006248    -0.027094  0.285323 -0.014001  0.118533
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Exited       -0.04782  -0.007138       -0.156128         0.012097     1.0

# %%
k.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
sns.pairplot(dataset)

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=False)

# %%
gender
# Out:
#       Female  Male
# 0          1     0
# 1          1     0
# 2          1     0
# 3          1     0
# 4          1     0
# ...      ...   ...
# 9995       0     1
# 9996       0     1
# 9997       1     0
# 9998       0     1
# 9999       1     0
#
# [10000 rows x 2 columns]

# %%
geography=pd.get_dummies(X["Geography"], drop_first=True)

# %%
pd.get_dummies?

# %%
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
## Concatenate the Data Frames

X=pd.concat([X,geography,gender],axis=1)

## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
X.shape
# Out:
# (10000, 12)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Female  Male
# 0               1        101348.88        0      0       1     0
# 1               1        112542.58        0      1       1     0
# 2               0        113931.57        0      0       1     0
# 3               0         93826.63        0      0       1     0
# 4               1         79084.10        0      1       1     0

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ...,  1.74309049,
#          1.09168714, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ..., -0.57369368,
#         -0.91601335,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.57369368,
#          1.09168714, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.57369368,
#         -0.91601335,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ...,  1.74309049,
#          1.09168714, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ..., -0.57369368,
#          1.09168714, -1.09168714]])

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.3.0

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.3.0'

# %%
pd.__version__
# Out:
# '1.1.4'

# %%
np.__version__
# Out:
# '1.18.5'

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
classifier = Sequential()
classifier.add(Dense(units=10,kernel_initializer ="he_uniform", activation ="relu", input_dim =12))
classifier.add(Dropout(0.3))
classifier.add(Dense(units=10, kernel_initializer ="he_uniform", activation="relu"))
classifier.add(Dropout(0.4))

classifier.add(Dense(units=1, kernel_initializer ="glorot_uniform", activation="sigmoid"))

classifier.compile(optimizer ="adam" , loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 10,kernel_initializer='he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(units = 10, kernel_initializer = 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 10)                130
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                110
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.add(Dense(units = 10, kernel_initializer = 'he_uniform',activation='relu'))

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
model_history = classifier.fit(X_train, y_train, validation_split=0.33, batch_size=100, epochs=100)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.7316 - accuracy: 0.5953 - val_loss: 0.5721 - val_accuracy: 0.7391
# Epoch 2/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6039 - accuracy: 0.7057 - val_loss: 0.5171 - val_accuracy: 0.7846
# Epoch 3/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5729 - accuracy: 0.7416 - val_loss: 0.4981 - val_accuracy: 0.7948
# Epoch 4/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5555 - accuracy: 0.7653 - val_loss: 0.4891 - val_accuracy: 0.7955
# Epoch 5/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5363 - accuracy: 0.7731 - val_loss: 0.4820 - val_accuracy: 0.7952
# Epoch 6/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5318 - accuracy: 0.7834 - val_loss: 0.4776 - val_accuracy: 0.7955
# Epoch 7/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5229 - accuracy: 0.7834 - val_loss: 0.4733 - val_accuracy: 0.7955
# Epoch 8/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5052 - accuracy: 0.7932 - val_loss: 0.4686 - val_accuracy: 0.7955
# Epoch 9/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5005 - accuracy: 0.7912 - val_loss: 0.4649 - val_accuracy: 0.7955
# Epoch 10/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5045 - accuracy: 0.7895 - val_loss: 0.4619 - val_accuracy: 0.7955
# Epoch 11/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.4990 - accuracy: 0.7936 - val_loss: 0.4592 - val_accuracy: 0.7955
# Epoch 12/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.4946 - accuracy: 0.7927 - val_loss: 0.4561 - val_accuracy: 0.7955
# Epoch 13/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.4881 - accuracy: 0.7946 - val_loss: 0.4537 - val_accuracy: 0.7955
# Epoch 14/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4851 - accuracy: 0.7960 - val_loss: 0.4515 - val_accuracy: 0.7955
# Epoch 15/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4863 - accuracy: 0.7953 - val_loss: 0.4493 - val_accuracy: 0.7955
# Epoch 16/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4809 - accuracy: 0.7972 - val_loss: 0.4470 - val_accuracy: 0.7955
# Epoch 17/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4733 - accuracy: 0.7987 - val_loss: 0.4440 - val_accuracy: 0.7955
# Epoch 18/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4694 - accuracy: 0.7979 - val_loss: 0.4425 - val_accuracy: 0.7955
# Epoch 19/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4726 - accuracy: 0.7962 - val_loss: 0.4410 - val_accuracy: 0.7955
# Epoch 20/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4709 - accuracy: 0.7975 - val_loss: 0.4400 - val_accuracy: 0.7955
# Epoch 21/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.4637 - accuracy: 0.8001 - val_loss: 0.4384 - val_accuracy: 0.7955
# Epoch 22/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4603 - accuracy: 0.8005 - val_loss: 0.4353 - val_accuracy: 0.7955
# Epoch 23/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4639 - accuracy: 0.8003 - val_loss: 0.4344 - val_accuracy: 0.7955
# Epoch 24/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4551 - accuracy: 0.8054 - val_loss: 0.4327 - val_accuracy: 0.7955
# Epoch 25/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4548 - accuracy: 0.8065 - val_loss: 0.4309 - val_accuracy: 0.7959
# Epoch 26/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4521 - accuracy: 0.8061 - val_loss: 0.4293 - val_accuracy: 0.7967
# Epoch 27/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4532 - accuracy: 0.8085 - val_loss: 0.4286 - val_accuracy: 0.7970
# Epoch 28/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4506 - accuracy: 0.8106 - val_loss: 0.4265 - val_accuracy: 0.7970
# Epoch 29/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4408 - accuracy: 0.8089 - val_loss: 0.4243 - val_accuracy: 0.7974
# Epoch 30/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4427 - accuracy: 0.8127 - val_loss: 0.4223 - val_accuracy: 0.7989
# Epoch 31/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4437 - accuracy: 0.8099 - val_loss: 0.4210 - val_accuracy: 0.7997
# Epoch 32/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4404 - accuracy: 0.8112 - val_loss: 0.4198 - val_accuracy: 0.8016
# Epoch 33/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4393 - accuracy: 0.8136 - val_loss: 0.4180 - val_accuracy: 0.8035
# Epoch 34/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4418 - accuracy: 0.8130 - val_loss: 0.4171 - val_accuracy: 0.8050
# Epoch 35/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4405 - accuracy: 0.8106 - val_loss: 0.4166 - val_accuracy: 0.8054
# Epoch 36/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4384 - accuracy: 0.8145 - val_loss: 0.4158 - val_accuracy: 0.8058
# Epoch 37/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4368 - accuracy: 0.8175 - val_loss: 0.4141 - val_accuracy: 0.8088
# Epoch 38/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4344 - accuracy: 0.8123 - val_loss: 0.4130 - val_accuracy: 0.8095
# Epoch 39/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4302 - accuracy: 0.8188 - val_loss: 0.4117 - val_accuracy: 0.8107
# Epoch 40/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4328 - accuracy: 0.8153 - val_loss: 0.4112 - val_accuracy: 0.8111
# Epoch 41/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4322 - accuracy: 0.8143 - val_loss: 0.4098 - val_accuracy: 0.8111
# Epoch 42/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4326 - accuracy: 0.8199 - val_loss: 0.4089 - val_accuracy: 0.8118
# Epoch 43/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4295 - accuracy: 0.8181 - val_loss: 0.4083 - val_accuracy: 0.8137
# Epoch 44/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4323 - accuracy: 0.8210 - val_loss: 0.4081 - val_accuracy: 0.8133
# Epoch 45/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4309 - accuracy: 0.8175 - val_loss: 0.4065 - val_accuracy: 0.8141
# Epoch 46/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4246 - accuracy: 0.8227 - val_loss: 0.4045 - val_accuracy: 0.8133
# Epoch 47/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4251 - accuracy: 0.8151 - val_loss: 0.4029 - val_accuracy: 0.8156
# Epoch 48/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4348 - accuracy: 0.8153 - val_loss: 0.4044 - val_accuracy: 0.8133
# Epoch 49/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4233 - accuracy: 0.8207 - val_loss: 0.4027 - val_accuracy: 0.8145
# Epoch 50/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4229 - accuracy: 0.8261 - val_loss: 0.4009 - val_accuracy: 0.8164
# Epoch 51/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8224 - val_loss: 0.4003 - val_accuracy: 0.8186
# Epoch 52/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4215 - accuracy: 0.8225 - val_loss: 0.3996 - val_accuracy: 0.8190
# Epoch 53/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4145 - accuracy: 0.8231 - val_loss: 0.3979 - val_accuracy: 0.8183
# Epoch 54/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8246 - val_loss: 0.3967 - val_accuracy: 0.8194
# Epoch 55/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4280 - accuracy: 0.8231 - val_loss: 0.3977 - val_accuracy: 0.8186
# Epoch 56/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4233 - accuracy: 0.8205 - val_loss: 0.3974 - val_accuracy: 0.8179
# Epoch 57/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4181 - accuracy: 0.8265 - val_loss: 0.3953 - val_accuracy: 0.8194
# Epoch 58/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4166 - accuracy: 0.8253 - val_loss: 0.3939 - val_accuracy: 0.8232
# Epoch 59/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.8261 - val_loss: 0.3929 - val_accuracy: 0.8201
# Epoch 60/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4153 - accuracy: 0.8237 - val_loss: 0.3928 - val_accuracy: 0.8201
# Epoch 61/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4160 - accuracy: 0.8252 - val_loss: 0.3921 - val_accuracy: 0.8201
# Epoch 62/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4229 - accuracy: 0.8209 - val_loss: 0.3927 - val_accuracy: 0.8179
# Epoch 63/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.8220 - val_loss: 0.3921 - val_accuracy: 0.8183
# Epoch 64/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4166 - accuracy: 0.8263 - val_loss: 0.3910 - val_accuracy: 0.8209
# Epoch 65/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4143 - accuracy: 0.8229 - val_loss: 0.3910 - val_accuracy: 0.8190
# Epoch 66/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.8218 - val_loss: 0.3904 - val_accuracy: 0.8190
# Epoch 67/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4149 - accuracy: 0.8240 - val_loss: 0.3898 - val_accuracy: 0.8198
# Epoch 68/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4136 - accuracy: 0.8205 - val_loss: 0.3884 - val_accuracy: 0.8232
# Epoch 69/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4090 - accuracy: 0.8224 - val_loss: 0.3869 - val_accuracy: 0.8247
# Epoch 70/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4125 - accuracy: 0.8224 - val_loss: 0.3866 - val_accuracy: 0.8247
# Epoch 71/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4159 - accuracy: 0.8216 - val_loss: 0.3874 - val_accuracy: 0.8201
# Epoch 72/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8263 - val_loss: 0.3863 - val_accuracy: 0.8209
# Epoch 73/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8255 - val_loss: 0.3863 - val_accuracy: 0.8201
# Epoch 74/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8280 - val_loss: 0.3857 - val_accuracy: 0.8247
# Epoch 75/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4159 - accuracy: 0.8222 - val_loss: 0.3864 - val_accuracy: 0.8220
# Epoch 76/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4085 - accuracy: 0.8266 - val_loss: 0.3859 - val_accuracy: 0.8236
# Epoch 77/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4103 - accuracy: 0.8238 - val_loss: 0.3847 - val_accuracy: 0.8266
# Epoch 78/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8212 - val_loss: 0.3840 - val_accuracy: 0.8258
# Epoch 79/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4092 - accuracy: 0.8240 - val_loss: 0.3838 - val_accuracy: 0.8243
# Epoch 80/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8229 - val_loss: 0.3835 - val_accuracy: 0.8220
# Epoch 81/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4126 - accuracy: 0.8246 - val_loss: 0.3825 - val_accuracy: 0.8281
# Epoch 82/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8242 - val_loss: 0.3823 - val_accuracy: 0.8266
# Epoch 83/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8263 - val_loss: 0.3822 - val_accuracy: 0.8277
# Epoch 84/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8278 - val_loss: 0.3829 - val_accuracy: 0.8273
# Epoch 85/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4099 - accuracy: 0.8214 - val_loss: 0.3830 - val_accuracy: 0.8232
# Epoch 86/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4083 - accuracy: 0.8244 - val_loss: 0.3823 - val_accuracy: 0.8277
# Epoch 87/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.8283 - val_loss: 0.3813 - val_accuracy: 0.8304
# Epoch 88/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.8261 - val_loss: 0.3821 - val_accuracy: 0.8281
# Epoch 89/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 0.8287 - val_loss: 0.3807 - val_accuracy: 0.8307
# Epoch 90/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4079 - accuracy: 0.8265 - val_loss: 0.3804 - val_accuracy: 0.8319
# Epoch 91/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3969 - accuracy: 0.8265 - val_loss: 0.3798 - val_accuracy: 0.8307
# Epoch 92/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8233 - val_loss: 0.3806 - val_accuracy: 0.8258
# Epoch 93/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8263 - val_loss: 0.3803 - val_accuracy: 0.8273
# Epoch 94/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4024 - accuracy: 0.8268 - val_loss: 0.3797 - val_accuracy: 0.8304
# Epoch 95/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4023 - accuracy: 0.8242 - val_loss: 0.3797 - val_accuracy: 0.8296
# Epoch 96/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3998 - accuracy: 0.8270 - val_loss: 0.3798 - val_accuracy: 0.8296
# Epoch 97/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4083 - accuracy: 0.8238 - val_loss: 0.3798 - val_accuracy: 0.8285
# Epoch 98/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4009 - accuracy: 0.8298 - val_loss: 0.3792 - val_accuracy: 0.8319
# Epoch 99/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3997 - accuracy: 0.8296 - val_loss: 0.3789 - val_accuracy: 0.8304
# Epoch 100/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4066 - accuracy: 0.8238 - val_loss: 0.3792 - val_accuracy: 0.8296

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 100,epochs = 100,callbacks = [histories])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-cdb7d67ab1ca> in <module>
#       1 # Fitting the ANN to the Training set
# ----> 2 model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 100,epochs = 100,callbacks = [histories])
#
# NameError: name 'histories' is not defined

# %%
model_history.params
# Out:
# {'verbose': 1, 'epochs': 100, 'steps': 54}

# %%
model_history.validation_data

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.show()

# %%
# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = classifier.predict(X_test)
y_pred =()

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
X_test[1].shape
# Out:
# (12,)

# %%
pd.DataFrame(X_test[:1])
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.552043 -0.368904  1.044737  0.879303 -0.921591  0.642595  0.968738
#
#          7         8         9         10        11
# 0  1.610857  1.754865 -0.573694  1.091687 -1.091687

# %%
X_test.shape
# Out:
# (2000, 12)

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred2=classifier.predict(X_test[:1])

# %%
y_pred2
# Out:
# array([[0.38332346]], dtype=float32)

# %%
y_pred2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-0b31a7eaa444> in <module>
# ----> 1 y_pred2.reshape(1,12)
#
# ValueError: cannot reshape array of size 1 into shape (1,12)

# %%
sc.inverse_transform(y_pred2.reshape(1,12))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-197-521686907623> in <module>
# ----> 1 sc.inverse_transform(y_pred2.reshape(1,12))
#
# ValueError: cannot reshape array of size 1 into shape (1,12)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-c77feef6d363> in <module>
# ----> 1 cm = confusion_matrix(y_test,y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
cm
# Out:
# array([[1510,   85],
#        [ 205,  200]], dtype=int64)

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.855
